# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
_ = sns.regplot(tips, x='total_bill', y='tip')

# %%
# Relacja pomiędzy wysokością rachunku a wysokością napiwków. Dopasowanie metodą najmniejszych kwadratów (najlepsze wpasowanie w dane).
# Jeżeli cień jest szerszy - słabsze dopasowanie.
# Tam, gdzie punkty są skupione, z większą pewnością można przewidzieć wynik napiwku.
